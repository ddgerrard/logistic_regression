# %% [markdown]
# # Logistic Regression

# %% [raw]
# # Class imbalance
# # https://towardsdatascience.com/practical-tips-for-class-imbalance-in-binary-classification-6ee29bcdb8a7

# %%
from keras import Sequential
from keras.layers import Dense
import numpy as np
from keras.datasets import mnist
from keras.constraints import max_norm
# Out:
# C:\Users\dgerrard\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def build_logistic_model(input_dim, output_dim):
    model = Sequential()
    model.add(Dense(output_dim, input_dim=input_dim, kernel_constraint=max_norm(1), activation='sigmoid'))

    return model

# %%
output_dim = 1
input_dim = 2
batch_size = 128 
nb_epoch = 20
nb_classes = 2

# %%
model = build_logistic_model(input_dim, output_dim)

# %%
X_train = np.random.uniform(0,0.5,(100000,2))
y_train = np.round(np.sum(X_train, axis=1))
X_val = np.random.uniform(0,0.5,(100000,2))
y_val = 1-np.round(np.sum(X_val, axis=1))

# %%
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy']) 
history = model.fit(X_train, y_train, batch_size=batch_size, nb_epoch=nb_epoch,verbose=1, validation_data=(X_val, y_val)) 
score = model.evaluate(X_val, y_val, verbose=0) 
print('Test score:', score[0]) 
print('Test accuracy:', score[1])
# Out:
# C:\Users\dgerrard\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/20
# 100000/100000 [==============================] - 1s 9us/step - loss: 0.6613 - acc: 0.6647 - val_loss: 0.7411 - val_acc: 0.2222
# Epoch 2/20
# 100000/100000 [==============================] - 1s 7us/step - loss: 0.6427 - acc: 0.8237 - val_loss: 0.7525 - val_acc: 0.1308
# Epoch 3/20
# 100000/100000 [==============================] - 1s 7us/step - loss: 0.6384 - acc: 0.8960 - val_loss: 0.7538 - val_acc: 0.0846
# Epoch 4/20
# 100000/100000 [==============================] - 1s 7us/step - loss: 0.6374 - acc: 0.9310 - val_loss: 0.7544 - val_acc: 0.0576
# Epoch 5/20
# 100000/100000 [==============================] - 1s 7us/step - loss: 0.6370 - acc: 0.9530 - val_loss: 0.7547 - val_acc: 0.0446
# Epoch 6/20
# 100000/100000 [==============================] - 1s 8us/step - loss: 0.6368 - acc: 0.9624 - val_loss: 0.7548 - val_acc: 0.0295
# Epoch 7/20
# 100000/100000 [==============================] - 1s 6us/step - loss: 0.6368 - acc: 0.9712 - val_loss: 0.7548 - val_acc: 0.0227
# Epoch 8/20
# 100000/100000 [==============================] - 1s 7us/step - loss: 0.6367 - acc: 0.9765 - val_loss: 0.7548 - val_acc: 0.0290
# Epoch 9/20
# 100000/100000 [==============================] - 1s 7us/step - loss: 0.6367 - acc: 0.9790 - val_loss: 0.7548 - val_acc: 0.0354
# Epoch 10/20
# 100000/100000 [==============================] - 1s 7us/step - loss: 0.6367 - acc: 0.9707 - val_loss: 0.7548 - val_acc: 0.0257
# Epoch 11/20
# 100000/100000 [==============================] - 1s 9us/step - loss: 0.6367 - acc: 0.9743 - val_loss: 0.7548 - val_acc: 0.0260
# Epoch 12/20
# 100000/100000 [==============================] - 1s 7us/step - loss: 0.6367 - acc: 0.9735 - val_loss: 0.7548 - val_acc: 0.0240
# Epoch 13/20
# 100000/100000 [==============================] - 1s 8us/step - loss: 0.6367 - acc: 0.9790 - val_loss: 0.7548 - val_acc: 0.0348
# Epoch 14/20
# 100000/100000 [==============================] - 1s 7us/step - loss: 0.6367 - acc: 0.9653 - val_loss: 0.7548 - val_acc: 0.0137
# Epoch 15/20
# 100000/100000 [==============================] - 1s 6us/step - loss: 0.6367 - acc: 0.9838 - val_loss: 0.7548 - val_acc: 0.0439
# Epoch 16/20
# 100000/100000 [==============================] - 1s 7us/step - loss: 0.6367 - acc: 0.9683 - val_loss: 0.7548 - val_acc: 0.0296
# Epoch 17/20
# 100000/100000 [==============================] - 1s 7us/step - loss: 0.6367 - acc: 0.9691 - val_loss: 0.7548 - val_acc: 0.0186
# Epoch 18/20
# 100000/100000 [==============================] - 1s 7us/step - loss: 0.6367 - acc: 0.9731 - val_loss: 0.7548 - val_acc: 0.0164
# Epoch 19/20
# 100000/100000 [==============================] - 1s 7us/step - loss: 0.6367 - acc: 0.9795 - val_loss: 0.7548 - val_acc: 0.0269
# Epoch 20/20
# 100000/100000 [==============================] - 1s 7us/step - loss: 0.6367 - acc: 0.9818 - val_loss: 0.7548 - val_acc: 0.0425
# Test score: 0.7548394715881348
# Test accuracy: 0.04245

# %%
model

# %%
weights, biases = model.layers[0].get_weights()

# %%
weights
# Out:
# array([[0.70738435],
#        [0.7068289 ]], dtype=float32)

# %%
biases
# Out:
# array([-0.33794102], dtype=float32)
